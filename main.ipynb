# %% [markdown]
# # Project Title: `Youtube Top 5000 Channels Dataset - Data Cleaning`
#
# ### Description: This notebook presents an analysis of Youtube Top 5000 Channels Dataset.
#
# ##### Dataset: https://www.kaggle.com/datasets/rahuldogra/top5000youtubechannels/data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('Data/top-5000-youtube-channels.csv') # loading the dataset
backup_data = pd.read_csv('Data/top-5000-youtube-channels.csv')

# %%
data #prints the dataset
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
data.head() #prints top 5 records of the dataset
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.tail() #prints bottom 5 records of the dataset
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
data.head(10) #prints top 10 records of the dataset
# Out:
#    Rank Grade                Channel name Video Uploads Subscribers  \
# 0   1st  A++                       Zee TV         82757    18752951
# 1   2nd  A++                     T-Series         12661    61196302
# 2   3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3   4th  A++                    SET India         27323    31180559
# 4   5th  A++                          WWE         36756    32852346
# 5   6th  A++                   Movieclips         30243    17149705
# 6   7th  A++                   netd müzik          8500    11373567
# 7   8th  A++        ABS-CBN Entertainment        100147    12149206
# 8   9th  A++              Ryan ToysReview          1140    16082927
# 9  10th  A++                  Zee Marathi         74607     2841811
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433
# 5  16618094724
# 6  23898730764
# 7  17202609850
# 8  24518098041
# 9   2591830307

# %%
data.head(-5) #prints the top 5 and hides then bottom 5 records
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %%
data.tail(-5) #prints the bottom 5 and hides then top 5 records
# Out:
#          Rank Grade           Channel name Video Uploads Subscribers  \
# 5         6th  A++              Movieclips         30243    17149705
# 6         7th  A++              netd müzik          8500    11373567
# 7         8th  A++   ABS-CBN Entertainment        100147    12149206
# 8         9th  A++         Ryan ToysReview          1140    16082927
# 9        10th  A++             Zee Marathi         74607     2841811
# ...       ...   ...                    ...           ...         ...
# 4995  4,996th   B+          Uras Benlioğlu           706     2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+             Mastersaint           110     3265735
# 4998  4,999th   B+          Bruce McIntosh          3475       32990
# 4999  5,000th   B+               SehatAQUA           254       21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# 9      2591830307
# ...           ...
# ...

# %%
f"Dataset consists a total of {data.shape[0]} rows and {data.shape[1]} columns"
# Out:
# 'Dataset consists a total of 5000 rows and 6 columns'

# %%
data.info() #gives complete information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
data.describe()
# Out:
#         Video views
# count  5.000000e+03
# mean   1.071449e+09
# std    2.003844e+09
# min    7.500000e+01
# 25%    1.862329e+08
# 50%    4.820548e+08
# 75%    1.124368e+09
# max    4.754884e+10

# %%
#converting all the floating numbers to 2 decimal numbers

pd.options.display.float_format = "{:.2f}".format

# %%
data.describe()
# Out:
#          Video views
# count        5000.00
# mean   1071449400.15
# std    2003843972.12
# min            75.00
# 25%     186232945.75
# 50%     482054780.00
# 75%    1124367826.75
# max   47548839843.00

# %%
data.describe(include="all")
# Out:
#            Rank Grade           Channel name Video Uploads Subscribers  \
# count      5000  5000                   5000          5000        5000
# unique     5000     6                   4993          2286        4612
# top     5,000th   B+   Learn Colors For Kids            26         --
# freq          1  2956                      2            17         387
# mean        NaN   NaN                    NaN           NaN         NaN
# std         NaN   NaN                    NaN           NaN         NaN
# min         NaN   NaN                    NaN           NaN         NaN
# 25%         NaN   NaN                    NaN           NaN         NaN
# 50%         NaN   NaN                    NaN           NaN         NaN
# 75%         NaN   NaN                    NaN           NaN         NaN
# max         NaN   NaN                    NaN           NaN         NaN
#
#           Video views
# count         5000.00
# unique            NaN
# top               NaN
# freq              NaN
# ...

# %%
# A empty value in 17th row
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
#replacing the empty value with NaN

data = data.replace('--',np.nan, regex=True)

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
#check for nulls in the dataset

print(data.isnull().sum())
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
# missing values by percentage

missing_percentage = ((data.isnull().sum())*100)/len(data)
print(missing_percentage)
# Out:
# Rank            0.00
# Grade           0.00
# Channel name    0.00
# Video Uploads   0.12
# Subscribers     7.74
# Video views     0.00
# dtype: float64

# %%
# heatmap to see the columns with missing values in the dataset
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.dropna()
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
data
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
# drops all the records with null values and inplace = True applies the changes to the source dataset
data.dropna(inplace=True)

# %%
data #now the null records have been removed
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
sns.heatmap(data.isnull()) #no null values in data
# Out:
# <Axes: >

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
# checking the datatypes of columns

data['Rank'].dtype
# Out:
# dtype('O')

# %%
# remove last 2 chars to convert the Rank column into int datatype

data['Rank'] = data['Rank'].str[0:-2]

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1  A++                       Zee TV         82757    18752951
# 1    2  A++                     T-Series         12661    61196302
# 2    3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4  A++                    SET India         27323    31180559
# 4    5  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.tail()
# Out:
#        Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998   B+         Mastersaint           110     3265735    311758426
# 4998  4,999   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000   B+           SehatAQUA           254       21172     73312511

# %%
# now that the chars are removed, we have to remove the commas now
data['Rank'] = data['Rank'].str.replace(',','')

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1  A++                       Zee TV         82757    18752951
# 1    2  A++                     T-Series         12661    61196302
# 2    3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4  A++                    SET India         27323    31180559
# 4    5  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.tail()
# Out:
#       Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4996   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4997   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4998   B+         Mastersaint           110     3265735    311758426
# 4998  4999   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5000   B+           SehatAQUA           254       21172     73312511

# %%
data['Rank'].dtype
# Out:
# dtype('O')

# %%
#converting the column into int datatype
data['Rank'] = data['Rank'].astype('int')

# %%
data['Rank'].dtype
# Out:
# dtype('int64')

# %%
#checking and then converting the remaining columns which have numerical values in it

print(data['Video Uploads'].dtype)
print(data['Subscribers'].dtype)
# Out:
# object
# object

# %%
data['Video Uploads'] = data['Video Uploads'].astype('int')
data['Subscribers'] = data['Subscribers'].astype('int')

# %%
print(data['Video Uploads'].dtype)
print(data['Subscribers'].dtype)
# Out:
# int64
# int64

# %%
data.dtypes
# Out:
# Rank              int64
# Grade            object
# Channel name     object
# Video Uploads     int64
# Subscribers       int64
# Video views       int64
# dtype: object

# %%
data.head()
# Out:
#    Rank Grade                Channel name  Video Uploads  Subscribers  \
# 0     1  A++                       Zee TV          82757     18752951
# 1     2  A++                     T-Series          12661     61196302
# 2     3  A++   Cocomelon - Nursery Rhymes            373     19238251
# 3     4  A++                    SET India          27323     31180559
# 4     5  A++                          WWE          36756     32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.tail()
# Out:
#       Rank Grade       Channel name  Video Uploads  Subscribers  Video views
# 4995  4996   B+      Uras Benlioğlu            706      2072942    441202795
# 4996  4997   B+   HI-TECH MUSIC LTD            797      1055091    377331722
# 4997  4998   B+         Mastersaint            110      3265735    311758426
# 4998  4999   B+      Bruce McIntosh           3475        32990     14563764
# 4999  5000   B+           SehatAQUA            254        21172     73312511

# %%
# to see what are all the values residing in Grade Column
data['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
#converting the string data into numerical data for the grade column
data['Grade'] = data['Grade'].map({'A++ ':5, 'A+ ':4, 'A ':3, 'A- ':2, 'B+ ':1})

# %%
data['Grade']
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 4995    1
# 4996    1
# 4997    1
# 4998    1
# 4999    1
# Name: Grade, Length: 4610, dtype: int64

# %%
data.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
#now convert the datatype of Grade column into int
data['Grade'] = data['Grade'].astype(int)

# %%
data['Grade'].dtype
# Out:
# dtype('int64')

# %%
data
# Out:
#       Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0        1      5                      Zee TV          82757     18752951
# 1        2      5                    T-Series          12661     61196302
# 2        3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3        4      5                   SET India          27323     31180559
# 4        5      5                         WWE          36756     32852346
# ...    ...    ...                         ...            ...          ...
# 4995  4996      1              Uras Benlioğlu            706      2072942
# 4996  4997      1           HI-TECH MUSIC LTD            797      1055091
# 4997  4998      1                 Mastersaint            110      3265735
# 4998  4999      1              Bruce McIntosh           3475        32990
# 4999  5000      1                   SehatAQUA            254        21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
data.dtypes
# Out:
# Rank              int64
# Grade             int64
# Channel name     object
# Video Uploads     int64
# Subscribers       int64
# Video views       int64
# dtype: object

# %%
data['Average Views'] = data['Video views'] / data['Video Uploads']

# %% [markdown]
# ##### 1. Find Average Views for each Channel

# %%
data
# Out:
#       Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0        1      5                      Zee TV          82757     18752951
# 1        2      5                    T-Series          12661     61196302
# 2        3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3        4      5                   SET India          27323     31180559
# 4        5      5                         WWE          36756     32852346
# ...    ...    ...                         ...            ...          ...
# 4995  4996      1              Uras Benlioğlu            706      2072942
# 4996  4997      1           HI-TECH MUSIC LTD            797      1055091
# 4997  4998      1                 Mastersaint            110      3265735
# 4998  4999      1              Bruce McIntosh           3475        32990
# 4999  5000      1                   SehatAQUA            254        21172
#
#       Video views  Average Views
# 0     20869786591      252181.53
# ...

# %% [markdown]
# ##### 2. Find Top 5 Channels with Maximum number of Video Uploads

# %%
data.sort_values(by='Video Uploads', ascending=False).head()
# Out:
#       Rank  Grade Channel name  Video Uploads  Subscribers  Video views  \
# 3453  3454      1   AP Archive         422326       746325    548619569
# 1149  1150      2     YTN NEWS         355996       820108   1640347646
# 2223  2224      1    SBS Drama         335521      1418619   1565758044
# 323    324      3     GMA News         269065      2599175   2786949164
# 2956  2957      1          MLB         267649      1434206   1329206392
#
#       Average Views
# 3453        1299.04
# 1149        4607.77
# 2223        4666.65
# 323        10357.90
# 2956        4966.23

# %% [markdown]
# ##### 3. Find Bottom 5 Channels with Maximum number of Video Uploads

# %%
data.sort_values(by='Video Uploads').head()
# data.sort_values(by='Video Uploads', ascending=True).head()
# Out:
#       Rank  Grade        Channel name  Video Uploads  Subscribers  \
# 4975  4976      1          Funny Kids              1       150091
# 628    629      3          cocoz toon              1      2162992
# 4474  4475      1           hyghhopes              1        15325
# 2404  2405      1  ItsHARSH007 Gaming              1        23499
# 4100  4101      1     DenzelCurryVEVO              1         8012
#
#       Video views  Average Views
# 4975     21933876    21933876.00
# 628     333012122   333012122.00
# 4474     14842098    14842098.00
# 2404           75          75.00
# 4100     25878252    25878252.00

# %% [markdown]
# ##### 4. Which Grade has a maximum number of video uploads?

# %%
colors = ['#FF5733', '#33FF57', '#3357FF', '#F333FF']
sns.barplot(x='Grade', y='Video Uploads', data=data, palette=colors)
plt.title("Grades v/s Video Uploads")
plt.show()
# Out:
# C:\Users\gouda\AppData\Local\Temp\ipykernel_20836\1036277816.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Grade', y='Video Uploads', data=data, palette=colors)
# C:\Users\gouda\AppData\Local\Temp\ipykernel_20836\1036277816.py:2: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Grade', y='Video Uploads', data=data, palette=colors)

# %% [markdown]
# ##### 4. Which Grade has highest Average Views?

# %%
colors = ['#FF5733', '#33FF57', '#3357FF', '#F333FF']
sns.barplot(x='Grade', y='Average Views', data=data, palette=colors)
plt.title('Grade v/s Average Views')
plt.show()
# Out:
# C:\Users\gouda\AppData\Local\Temp\ipykernel_20836\1094257174.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Grade', y='Average Views', data=data, palette=colors)
# C:\Users\gouda\AppData\Local\Temp\ipykernel_20836\1094257174.py:2: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Grade', y='Average Views', data=data, palette=colors)

# %% [markdown]
# ##### 5. Which Grade has Highest Number of Subscribers?

# %%
data.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views  Average Views
# 0  20869786591      252181.53
# 1  47548839843     3755535.89
# 2   9793305082    26255509.60
# 3  22675948293      829921.62
# 4  26273668433      714813.05

# %%
colors = ['#FF5733', '#33FF57', '#3357FF', '#F333FF']
sns.barplot(x='Grade', y='Subscribers', data=data, palette=colors)
# Out:
# C:\Users\gouda\AppData\Local\Temp\ipykernel_20836\3633331018.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Grade', y='Subscribers', data=data, palette=colors)
# C:\Users\gouda\AppData\Local\Temp\ipykernel_20836\3633331018.py:2: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Grade', y='Subscribers', data=data, palette=colors)
# <Axes: xlabel='Grade', ylabel='Subscribers'>

# %% [markdown]
# ##### 6. Which Grade has Highest Video Views?

# %%
# colors = ['#FF5733', '#33FF57', '#3357FF', '#F333FF']
sns.barplot(x='Grade', y='Video views', data=data, palette=colors)
# Out:
# C:\Users\gouda\AppData\Local\Temp\ipykernel_20836\669921717.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Grade', y='Video views', data=data, palette=colors)
# C:\Users\gouda\AppData\Local\Temp\ipykernel_20836\669921717.py:2: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Grade', y='Video views', data=data, palette=colors)
# <Axes: xlabel='Grade', ylabel='Video views'>

# %%
data.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views  Average Views
# 0  20869786591      252181.53
# 1  47548839843     3755535.89
# 2   9793305082    26255509.60
# 3  22675948293      829921.62
# 4  26273668433      714813.05

# %%
data
# Out:
#       Rank  Grade        Channel name  Video Uploads  Subscribers  \
# 628    629      3          cocoz toon              1      2162992
# 314    315      3   icanrockyourworld              8      3891968
# 613    614      3           AdeleVEVO             31     16270830
# 389    390      3           Bad Bunny             11     12685253
# 1120  1121      2         Danny Ocean              8      2861917
# 1264  1265      2       CrazyFrogVEVO             12      4585990
# 84      85      3  Galinha Pintadinha             47     13312085
# 246    247      3   MTZ Manuel Turizo              9      3531337
# 304    305      3     TaylorSwiftVEVO             86     28133287
# 13      14      4               Ozuna             50     18824912
#
#       Video views  Average Views
# 628     333012122   333012122.00
# 314    2420286079   302535759.88
# 613    7414111263   239164879.45
# 389    2612504875   237500443.18
# 1120   1690503137   211312892.12
# 1264   2477475081   206456256.75
# ...

# %%
df = pd.DataFrame(data)
df.to_csv('Data/updated.csv',index=False)

# %%
data.sort_values(by='Average Views', ascending=False).head(10)
# Out:
#       Rank  Grade        Channel name  Video Uploads  Subscribers  \
# 628    629      3          cocoz toon              1      2162992
# 314    315      3   icanrockyourworld              8      3891968
# 613    614      3           AdeleVEVO             31     16270830
# 389    390      3           Bad Bunny             11     12685253
# 1120  1121      2         Danny Ocean              8      2861917
# 1264  1265      2       CrazyFrogVEVO             12      4585990
# 84      85      3  Galinha Pintadinha             47     13312085
# 246    247      3   MTZ Manuel Turizo              9      3531337
# 304    305      3     TaylorSwiftVEVO             86     28133287
# 13      14      4               Ozuna             50     18824912
#
#       Video views  Average Views
# 628     333012122   333012122.00
# 314    2420286079   302535759.88
# 613    7414111263   239164879.45
# 389    2612504875   237500443.18
# 1120   1690503137   211312892.12
# 1264   2477475081   206456256.75
# ...
